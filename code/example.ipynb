# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.linear_model import LinearRegression   # Example import
import keras

# %%
df1 = pd.DataFrame({
    'Col A': [1,2,3],
    'Col B': [0.5, 0.8, 0.3]
})

df2 = pd.DataFrame(
    [[1,0.5], [2, 0.8], [3, 0.3]], 
    columns=['A', 'B']
)

print(df1)
print(df2)
# Out:
#    Col A  Col B
# 0      1    0.5
# 1      2    0.8
# 2      3    0.3
#    A    B
# 0  1  0.5
# 1  2  0.8
# 2  3  0.3

# %%
new_arr = np.array([1,2,3])
print(new_arr)
# Out:
# [1 2 3]

# %%
students = ['A', 'B', 'C']
grades = [98, 87, 56]

plt.xticks(range(len(students)), students)
plt.xlabel('Students')
plt.ylabel('Grades')
plt.title('Student grades')
plt.bar(range(len(students)), grades)

plt.show()
